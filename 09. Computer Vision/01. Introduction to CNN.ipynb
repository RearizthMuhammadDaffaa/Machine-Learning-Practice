# %% [markdown]
# https://cs231n.github.io/

# %% [markdown]
# Mengapa pakai CNN untuk Computer Vision?

# %% [markdown]
# ## 1. CNN dapat dipakai untuk ekstraksi fitur

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gambar wajah dapat diekstraksi menjadi gambar bagian-bagian pada wajah, garis-garis yang membentuk wajah, etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. CNN banyak dipakai sebagai Filter
# https://setosa.io/ev/image-kernels/

# %% [markdown]
# # Stride & Padding in CNN
# Stride : step dalam konvolusi.
# <br>Stride yang besar menyebabkan hasil konvolusi yang kecil

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Padding : Penambahan lapisan (supaya mungkin hasil konvolusinya tetap sama dengan gambar awal).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
