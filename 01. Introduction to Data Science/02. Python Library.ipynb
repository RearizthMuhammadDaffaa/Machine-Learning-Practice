# %% [markdown]
# Di awal, Python sudah memiliki beberapa _build-in_ function.
#
# Contohnya :
# - print()
# - secara lengkap ada di https://docs.python.org/3/library/functions.html
#
#
# Beberapa function lain bisa kita buat sendiri, atau bahkan bisa kita dapatkan melalui library/package yang sudah dibuat oleh developer.

# %%
# cara melihat library/package yang sudah terinstall di engine kita
# !pip list

# %%
# cara menginstall suatu package
# ada 2 market sumber package, yaitu
# 1. pypi   : pip install <nama_package>
#    Contoh : pip install numpy
#             (akan terinstall numpy dengan versi terbaru)
#    Contoh : pip install numpy==1.25.0
#             (akan terinstall numpy dengan versi yang kita minta)

# 2. conda  : conda install <nama_package>
#    Contoh : conda install numpy
#             (akan terinstall numpy dengan versi terbaru)


# Uninstall : pip uninstall <package_name>
# Upgrade   : pip upgrade <package_name>

# %%
def sqrt(nilai):
    hasil_akar = nilai**(1/2)
    return round(hasil_akar,2)
sqrt(36.1)
# Out:
# 6.01

# %% [markdown]
# # 1. Numerical Python (Numpy)
# ## 1.1. Cara Memanggil Package

# %%
# Fungsi abs dari built-in function di Python
abs(-9)
# Out:
# 9

# %%
# Cara 1
import numpy
numpy.abs(-25)
# Out:
# 25

# %%
# Cara 2 :  paling sering dipilih
import numpy as np
np.abs(-25)
# Out:
# 25

# %%
# Cara 3 : import semua functionnya langsung
from numpy import abs,sqrt   # import fungsi abs dari numpy
from numpy import *          # semua fungsi dari numpy diimport

# %%
# Dari manakah sumber function sqrt di bawah?
sqrt(36.1)
# Out:
# 6.01

# %% [markdown]
# ## 1.2. Function arange
# membuat suatu array dengan range tertentu

# %%
# start : stop : step
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %% [markdown]
# ## 1.3. Fungsi linspace
# membuat array dari suatu titik ke titik lain sebanyak n dengan interval yang sama

# %%
np.linspace(1,10,20)
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %% [markdown]
# # 2. Python Data Analysis (Pandas)
# package untuk kerangka dataframe, analisa data, dsb.

# %%
import pandas as pd

# %% [markdown]
# ## 2.1. Membuat DataFrame baru

# %%
data = {'nama_siswa' :['A','B','C'],
        'nilai_siswa':[70,75,65]}

pd.DataFrame(data)
# Out:
#   nama_siswa  nilai_siswa
# 0          A           70
# 1          B           75
# 2          C           65

# %% [markdown]
# ## 2.2. Membaca DataFrame

# %%
# Excel punya beberapa extension file, contohnya : .xlsx,.csv (mayoritas)
df = pd.read_csv('https://raw.githubusercontent.com/reynoldms/csv_data/main/Automobile_data.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/Course Files/Course-Net/02. Kampus Merdeka/01. Introduction to Data Science/german_credit_data.csv')

# %%
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %% [markdown]
# ## 2.3. Show data teratas dan terakhir

# %%
# menampilkan n data teratas
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
# menampilkan n data terakhir
df.tail()
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose  Risk
# 995        12  furniture/equipment  good
# 996        30                  car  good
# 997        12             radio/TV  good
# 998        45             radio/TV   bad
# 999        45                  car  good

# %% [markdown]
# ## 2.4. Menampilkan info Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.2+ KB

# %% [markdown]
# terdapat missing value di kolom `Saving accounts` dan `Checking account`

# %% [markdown]
# ## 2.5. Statistic Descriptive

# %%
df.describe(include='all')
# Out:
#                 Age   Sex          Job Housing Saving accounts  \
# count   1000.000000  1000  1000.000000    1000             817
# unique          NaN     2          NaN       3               4
# top             NaN  male          NaN     own          little
# freq            NaN   690          NaN     713             603
# mean      35.546000   NaN     1.904000     NaN             NaN
# std       11.375469   NaN     0.653614     NaN             NaN
# min       19.000000   NaN     0.000000     NaN             NaN
# 25%       27.000000   NaN     2.000000     NaN             NaN
# 50%       33.000000   NaN     2.000000     NaN             NaN
# 75%       42.000000   NaN     2.000000     NaN             NaN
# max       75.000000   NaN     3.000000     NaN             NaN
#
#        Checking account  Credit amount     Duration Purpose  Risk
# count               606    1000.000000  1000.000000    1000  1000
# unique                3            NaN          NaN       8     2
# ...
