# %% [markdown]
# `Word Embedding` atau `Word Modelling` atau `Vektorisasi` adalah proses mengubah kata/kalimat menjadi sebuah vektor.

# %% [markdown]
# # 1. Import Package

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %% [markdown]
# # 2. Data

# %%
text = ['Ini adalah pensil, tapi itu adalah pulpen',
        'Ini adalah pulpen, tapi itu adalah pensil',
        'Itu adalah pensil.',
        'Saya mau beli pulpen.',
        'Saya ada pulpen itu, tapi tidak ada pensil itu.',
        'Saya tidak ada pensil ini',
        'Saya mau beli pulpen dan pensil',
        'Ini adalah pulpen']

# %% [markdown]
# # 3. Proses Word Embedding

# %% [markdown]
# ## 3.1. BoW (Bag of Words)
# BoW adalah proses mengubah kalimat menjadi vektor dengan mempertimbangkan frekuensi dari setiap kata-kata yang muncul.

# %% [markdown]
# ### Bow without Removing StopWords

# %%
## BoW pakai CountVectorizer
bow_model  = CountVectorizer()
bow_matrix = bow_model.fit_transform(text)

## Sanity Check
pd.DataFrame(bow_matrix.toarray(),
             columns=bow_model.get_feature_names_out(),
             index=text)
# Out:
#                                                  ada  adalah  beli  dan  ini  \
# Ini adalah pensil, tapi itu adalah pulpen          0       2     0    0    1
# Ini adalah pulpen, tapi itu adalah pensil          0       2     0    0    1
# Itu adalah pensil.                                 0       1     0    0    0
# Saya mau beli pulpen.                              0       0     1    0    0
# Saya ada pulpen itu, tapi tidak ada pensil itu.    2       0     0    0    0
# Saya tidak ada pensil ini                          1       0     0    0    1
# Saya mau beli pulpen dan pensil                    0       0     1    1    0
# Ini adalah pulpen                                  0       1     0    0    1
#
#                                                  itu  mau  pensil  pulpen  \
# Ini adalah pensil, tapi itu adalah pulpen          1    0       1       1
# Ini adalah pulpen, tapi itu adalah pensil          1    0       1       1
# Itu adalah pensil.                                 1    0       1       0
# Saya mau beli pulpen.                              0    1       0       1
# Saya ada pulpen itu, tapi tidak ada pensil itu.    2    0       1       1
# Saya tidak ada pensil ini                          0    0       1       0
# Saya mau beli pulpen dan pensil                    0    1       1       1
# Ini adalah pulpen                                  0    0       0       1
#
#                                                  saya  tapi  tidak
# Ini adalah pensil, tapi itu adalah pulpen           0     1      0
# Ini adalah pulpen, tapi itu adalah pensil           0     1      0
# Itu adalah pensil.                                  0     0      0
# Saya mau beli pulpen.                               1     0      0
# Saya ada pulpen itu, tapi tidak ada pensil itu.     1     1      1
# Saya tidak ada pensil ini                           1     0      1
# Saya mau beli pulpen dan pensil                     1     0      0
# Ini adalah pulpen                                   0     0      0

# %% [markdown]
# ### BoW with Removing StopWords

# %%
# !pip install Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
list_sw_sastrawi = StopWordRemoverFactory().get_stop_words()
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
## BoW pakai CountVectorizer
bow_model  = CountVectorizer(stop_words=list_sw_sastrawi)
bow_matrix = bow_model.fit_transform(text)

## Sanity Check
pd.DataFrame(bow_matrix.toarray(),
             columns=bow_model.get_feature_names_out(),
             index=text)
# Out:
#                                                  beli  mau  pensil  pulpen
# Ini adalah pensil, tapi itu adalah pulpen           0    0       1       1
# Ini adalah pulpen, tapi itu adalah pensil           0    0       1       1
# Itu adalah pensil.                                  0    0       1       0
# Saya mau beli pulpen.                               1    1       0       1
# Saya ada pulpen itu, tapi tidak ada pensil itu.     0    0       1       1
# Saya tidak ada pensil ini                           0    0       1       0
# Saya mau beli pulpen dan pensil                     1    1       1       1
# Ini adalah pulpen                                   0    0       0       1

# %% [markdown]
# ## 3.2. TF-IDF (Term Frequency - Inverse Document Frequency)
# TF-IDF adalah proses mengubah kalimat menjadi vektor yang diproses menggunakan teknik BoW, lalu discaling menggunakan inversenya.
#
# Efek dari TF-IDF :
# 1. Kata-kata yang sering muncul, akan dianggap tidak penting karena seakan-akan tidak ada pembeda antara kalimat yang satu dengan kaliman yang lainnya.
# 2. Kata-kata yang jarang muncul akan dikuatkan.

# %% [markdown]
# ### TF-IDF without Removing Stopwords

# %%
## TF-IDF pakai TfidfVectorizer
bow_model  = TfidfVectorizer()
bow_matrix = bow_model.fit_transform(text)

## Sanity Check
pd.DataFrame(bow_matrix.toarray(),
             columns=bow_model.get_feature_names_out(),
             index=text)
# Out:
#                                                       ada    adalah      beli  \
# Ini adalah pensil, tapi itu adalah pulpen        0.000000  0.684266  0.000000
# Ini adalah pulpen, tapi itu adalah pensil        0.000000  0.684266  0.000000
# Itu adalah pensil.                               0.000000  0.617675  0.000000
# Saya mau beli pulpen.                            0.000000  0.000000  0.584411
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.655199  0.000000  0.000000
# Saya tidak ada pensil ini                        0.534494  0.000000  0.000000
# Saya mau beli pulpen dan pensil                  0.000000  0.000000  0.460912
# Ini adalah pulpen                                0.000000  0.617675  0.000000
#
#                                                       dan       ini       itu  \
# Ini adalah pensil, tapi itu adalah pulpen        0.000000  0.342133  0.342133
# Ini adalah pulpen, tapi itu adalah pensil        0.000000  0.342133  0.342133
# Itu adalah pensil.                               0.000000  0.000000  0.617675
# Saya mau beli pulpen.                            0.000000  0.000000  0.000000
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.000000  0.000000  0.495716
# Saya tidak ada pensil ini                        0.000000  0.404392  0.000000
# Saya mau beli pulpen dan pensil                  0.549963  0.000000  0.000000
# Ini adalah pulpen                                0.000000  0.617675  0.000000
#
#                                                       mau    pensil    pulpen  \
# Ini adalah pensil, tapi itu adalah pulpen        0.000000  0.269631  0.269631
# Ini adalah pulpen, tapi itu adalah pensil        0.000000  0.269631  0.269631
# Itu adalah pensil.                               0.000000  0.486781  0.000000
# Saya mau beli pulpen.                            0.584411  0.000000  0.348460
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.000000  0.195334  0.195334
# Saya tidak ada pensil ini                        0.000000  0.318696  0.000000
# Saya mau beli pulpen dan pensil                  0.460912  0.274822  0.274822
# Ini adalah pulpen                                0.000000  0.000000  0.486781
#
#                                                      saya      tapi     tidak
# Ini adalah pensil, tapi itu adalah pulpen        0.000000  0.390216  0.000000
# Ini adalah pulpen, tapi itu adalah pensil        0.000000  0.390216  0.000000
# Itu adalah pensil.                               0.000000  0.000000  0.000000
# Saya mau beli pulpen.                            0.442159  0.000000  0.000000
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.247858  0.282691  0.327599
# Saya tidak ada pensil ini                        0.404392  0.000000  0.534494
# Saya mau beli pulpen dan pensil                  0.348721  0.000000  0.000000
# Ini adalah pulpen                                0.000000  0.000000  0.000000

# %% [markdown]
# ### TF-IDF with Removing Stopwords

# %%
## TF-IDF pakai TfidfVectorizer
bow_model  = TfidfVectorizer(stop_words=list_sw_sastrawi)
bow_matrix = bow_model.fit_transform(text)

## Sanity Check
pd.DataFrame(bow_matrix.toarray(),
             columns=bow_model.get_feature_names_out(),
             index=text)
# Out:
#                                                      beli       mau    pensil  \
# Ini adalah pensil, tapi itu adalah pulpen        0.000000  0.000000  0.707107
# Ini adalah pulpen, tapi itu adalah pensil        0.000000  0.000000  0.707107
# Itu adalah pensil.                               0.000000  0.000000  1.000000
# Saya mau beli pulpen.                            0.651563  0.651563  0.000000
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.000000  0.000000  0.707107
# Saya tidak ada pensil ini                        0.000000  0.000000  1.000000
# Saya mau beli pulpen dan pensil                  0.607339  0.607339  0.362131
# Ini adalah pulpen                                0.000000  0.000000  0.000000
#
#                                                    pulpen
# Ini adalah pensil, tapi itu adalah pulpen        0.707107
# Ini adalah pulpen, tapi itu adalah pensil        0.707107
# Itu adalah pensil.                               0.000000
# Saya mau beli pulpen.                            0.388500
# Saya ada pulpen itu, tapi tidak ada pensil itu.  0.707107
# Saya tidak ada pensil ini                        0.000000
# Saya mau beli pulpen dan pensil                  0.362131
# Ini adalah pulpen                                1.000000

# %% [markdown]
# # 4. Kekurangan BoW dan TF-IDF

# %%
text_new = ['Saya mau beli pulpen.',
            'pulpen mau beli saya']

# model  = CountVectorizer()
model  = TfidfVectorizer()

matrix = model.fit_transform(text_new)

pd.DataFrame(matrix.toarray(),
             columns=model.get_feature_names_out(),
             index=text_new)
# Out:
#                        beli  mau  pulpen  saya
# Saya mau beli pulpen.   0.5  0.5     0.5   0.5
# pulpen mau beli saya    0.5  0.5     0.5   0.5

# %% [markdown]
# Urutan kata dalam kalimat tidak mempengaruhi hasil vektorisasi walaupun sebenarnya bisa beda arti.
# <br> Perhatikan kalimat 1 dan kalimat 2. Walaupun beda susunan sehingga artinya beda, tapi BoW dan TF-IDF menganggapnya sama.
#
# Untuk handling case ini, kita bisa manfaatkan `n-gram`.
#
# Yang kita pakai sebelumnya, kita sudah `n-gram=1` atau sering disebut sebagai monogram.

# %%
# model  = TfidfVectorizer(ngram_range=(1,2))
model  = CountVectorizer(ngram_range=(1,2))

matrix = model.fit_transform(text_new)

pd.DataFrame(matrix.toarray(),
             columns=model.get_feature_names_out(),
             index=text_new)
# Out:
#                        beli  beli pulpen  beli saya  mau  mau beli  pulpen  \
# Saya mau beli pulpen.     1            1          0    1         1       1
# pulpen mau beli saya      1            0          1    1         1       1
#
#                        pulpen mau  saya  saya mau
# Saya mau beli pulpen.           0     1         1
# pulpen mau beli saya            1     1         0
